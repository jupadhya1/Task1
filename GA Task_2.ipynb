# %%
# Student Version 1
#!/usr/bin/env python

import pandas as pd
import numpy as np
# Incorrect usage of the import function while importing Linear Regression class
# Should import the module from sklearn.model_selection import cross_val_score, train_test_split
# Please do include the model_selection module otherwise the following two imports will not work

# Below should be from sklearn.linear_model import LinearRegression
from sklearn import LinearRegression
#from sklearn.linear_model import LinearRegression
from sklearn.cross_validation import cross_val_score

# Load data
# d data frame variable is ambigous use data since we are using data (DF variable) in the further execution of code

#d = pd.read_csv('../data/train.csv')
data = pd.read_csv('../data/train.csv')


# Setup data for prediction
# x1 and x2 are too geneic to use here instead use the convention to proper representation
x1 = data.SalaryNormalized
x2 = pd.get_dummies(data.ContractType)

# Setup model
model = LinearRegression()

# Evaluate model

# No need to further import the modules since it will not use 
from sklearn.cross_validation import cross_val_score
from sklearn.cross_validation import train_test_split

# should include the following ======
# Code has been modified to use the below points :
# Split arrays or matrices into random train and test subsets
# List containing train-test split of inputs.(generally 20% hold data set)

split_percent = 0.2
X_train, X_test, y_train, y_test = train_test_split(x1, x2, test_size = split_percent)

# Strongly recommended to use the y as your labeled data and X as predictor 


# Should use model.fit() on your data to train before evaluation
# model.fit(train, test)

# switch x1 and x2, because cross_val_score needs training data as 2nd param and test as 3rd param
# note: there are 2 classes, so cv values should be 2
scores = cross_val_score(model, x2, x1, cv=1, scoring='mean_absolute_error')
print(scores.mean())

# %%
# Student Version 2
#!/usr/bin/env python
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# import below should be from sklearn.model_selection import cross_val_score
from sklearn.cross_validation import cross_val_score

# Load data
data = pd.read_csv('../data/train.csv')


# Setup data for prediction
# Please switch the varbale names since y seems to be your trainning data and X seems to be the lables

y = data.SalaryNormalized
X = pd.get_dummies(data.ContractType)


# Setup model
model = LinearRegression()

# Evaluate model
# Please switch  X and y for order is (train, test) inside cross_val_score() function call
scores = cross_val_score(model, X, y, cv=5, scoring='mean_absolute_error')
print(scores.mean())
